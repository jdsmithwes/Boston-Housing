# %% [markdown]
# Boston Housing Data Project

# %%
import pandas as pd

# %matplotlib notebook
import matplotlib.pyplot as plt
plt.style.available


df=pd.read_csv('train.csv')

# %% [markdown]
# Summary Data

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %% [markdown]
# Subsets for future study
#
# For further analysis, I thought it would be interesting to use a major feature of Boston, the Charles River, to examine how whether there is a correlation between proximity to the river and home value. To complete this analysis, I will look at the chas,medv, and rad columns.

# %%
Charles = df['chas'] == 1
Not_Charles = df['chas'] != 1
Value = df['medv']
Work = df['dis']

# %% [markdown]
# Summary data for Home Value tab - (values in thousands, multiply figures by 10)

# %%
Value.describe()
# Out:
# count    333.000000
# mean      22.768769
# std        9.173468
# min        5.000000
# 25%       17.400000
# 50%       21.600000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# Summary data for Employment Centers

# %%
Work.describe()
# Out:
# count    333.000000
# mean       3.709934
# std        1.981123
# min        1.129600
# 25%        2.122400
# 50%        3.092300
# 75%        5.116700
# max       10.710300
# Name: dis, dtype: float64

# %% [markdown]
# The above summary data will be revisited to compare results against measures of central tendency and dispersion. Since Charles River data is binary (1 or 0), two new dataframes will be created to analyze home values near the river versus those further away. Also, it will be worth noting how proximity to major employment centers influences home values.

# %%
Near_Charles = df[Charles]
Near_Charles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 97 to 246
# Data columns (total 15 columns):
# ID         20 non-null int64
# crim       20 non-null float64
# zn         20 non-null float64
# indus      20 non-null float64
# chas       20 non-null int64
# nox        20 non-null float64
# rm         20 non-null float64
# age        20 non-null float64
# dis        20 non-null float64
# rad        20 non-null int64
# tax        20 non-null int64
# ptratio    20 non-null float64
# black      20 non-null float64
# lstat      20 non-null float64
# medv       20 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 2.5 KB

# %% [markdown]
# The summary above of homes near the Charles River includes 20 items of data.

# %%
Away_Charles = df[Not_Charles]
Away_Charles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 313 entries, 0 to 332
# Data columns (total 15 columns):
# ID         313 non-null int64
# crim       313 non-null float64
# zn         313 non-null float64
# indus      313 non-null float64
# chas       313 non-null int64
# nox        313 non-null float64
# rm         313 non-null float64
# age        313 non-null float64
# dis        313 non-null float64
# rad        313 non-null int64
# tax        313 non-null int64
# ptratio    313 non-null float64
# black      313 non-null float64
# lstat      313 non-null float64
# medv       313 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %% [markdown]
# Meanwhile, there are 313 homes that are away from the Charles River.

# %%
print(Near_Charles.describe())
# Out:
#                ID       crim         zn      indus  chas        nox  \
# count   20.000000  20.000000  20.000000  20.000000  20.0  20.000000
# mean   255.600000   2.163972   8.500000  12.330000   1.0   0.593595
# std     75.913663   2.885734  21.830688   6.505255   0.0   0.146237
# min    143.000000   0.015010   0.000000   1.210000   1.0   0.401000
# 25%    211.250000   0.200377   0.000000   6.200000   1.0   0.489000
# 50%    236.000000   0.572070   0.000000  12.240000   1.0   0.528500
# 75%    302.250000   3.453213   0.000000  18.100000   1.0   0.693500
# max    373.000000   8.982960  90.000000  19.580000   1.0   0.871000
#
#               rm         age        dis        rad         tax   ptratio  \
# count  20.000000   20.000000  20.000000  20.000000   20.000000  20.00000
# mean    6.577750   75.815000   3.069540   9.900000  394.550000  17.38500
# std     0.814341   22.808638   1.343724   8.534142  171.795005   2.22906
# ...

# %% [markdown]
# Based on the analysis above, homes near the Charles River have a median home value of $260,500.

# %%
print(Away_Charles.describe())
# Out:
#                ID        crim          zn       indus   chas         nox  \
# count  313.000000  313.000000  313.000000  313.000000  313.0  313.000000
# mean   250.654952    3.436787   10.829073   11.227252    0.0    0.554815
# std    151.365227    7.544289   22.754198    7.032974    0.0    0.112555
# min      1.000000    0.006320    0.000000    0.740000    0.0    0.385000
# 25%    118.000000    0.078750    0.000000    4.950000    0.0    0.453000
# 50%    245.000000    0.245220    0.000000    9.690000    0.0    0.538000
# 75%    387.000000    3.678220   12.500000   18.100000    0.0    0.624000
# max    506.000000   73.534100  100.000000   27.740000    0.0    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  313.000000  313.000000  313.000000  313.000000  313.000000  313.000000
# mean     6.245674   67.741534    3.750853    9.616613  410.220447   18.515974
# ...

# %% [markdown]
# Based on the analysis above, homes away from the Charles River have a median value of $212,000. Finally, by analyzing the correlation coefficient, we can firmly state whether being near the Charles River has a statistically significant impact on home values in Boston.

# %%
df.corr()
# Out:
#                ID      crim        zn     indus      chas       nox        rm  \
# ID       1.000000  0.456312 -0.155639  0.421978  0.007958  0.440185 -0.112790
# crim     0.456312  1.000000 -0.210913  0.422228 -0.041195  0.463001 -0.310180
# zn      -0.155639 -0.210913  1.000000 -0.518679 -0.024442 -0.501990  0.328197
# indus    0.421978  0.422228 -0.518679  1.000000  0.037496  0.750087 -0.440365
# chas     0.007958 -0.041195 -0.024442  0.037496  1.000000  0.080275  0.112251
# nox      0.440185  0.463001 -0.501990  0.750087  0.080275  1.000000 -0.338515
# rm      -0.112790 -0.310180  0.328197 -0.440365  0.112251 -0.338515  1.000000
# age      0.257300  0.379034 -0.544513  0.638378  0.068286  0.736000 -0.248573
# dis     -0.356461 -0.397067  0.637142 -0.702327 -0.081834 -0.769364  0.269191
# rad      0.707526  0.666636 -0.303663  0.569779  0.007714  0.612180 -0.272783
# tax      0.686246  0.617081 -0.311180  0.708313 -0.021826  0.670722 -0.356987
# ...

# %% [markdown]
# With a correlation coefficient of .20, there is a positive correlation between proximity to the Charles River and a home's value in Boston. Additionally, the correlation coefficient of .25 has a more positive relationship to home value. This would suggest that a home's value will more likely be greater based on its proximity to employment than the Charles River. However, the hard data that shows a median home value of $260k for homes near the Charles River is much larger than the $212k median value of homes away from the Charles River.
#
# An inference can be made that while homes near the Charles River are more valuable, future home value appreciation will be driven more by proximity to employment than it is the famous Charles River. This finding is inline with more individuals preferring not to have long commutes to work.

# %% [markdown]
# Crime Data Split
#
# Based on the correlation table above, the prediction that homes near the Charles River enjoy a lower rate of crime per capita than those that are further away. Additionally, the data supports the widely-held belief that as crime increases, the value of homes decreases. To filter the crime data, two dataframes can be created that detail home values in high crime areas versus low crime ones. High crime areas have per capita rates higher than the median of .26 and low crime areas will have a median below .26

# %%
High = df['crim'] >=.26
Low = df['crim'] <= .26

# %%
High_Crime = df[High]
Low_Crime = df[Low]

# %%
High_Crime.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean   309.532934    6.606155    1.221557   15.311138    0.083832    0.638701
# std    142.203900    9.319135    4.858729    5.459720    0.277970    0.098771
# min     14.000000    0.261690    0.000000    3.970000    0.000000    0.431000
# 25%    170.500000    0.788055    0.000000    9.900000    0.000000    0.544000
# 50%    363.000000    3.678220    0.000000   18.100000    0.000000    0.631000
# 75%    434.500000    9.084990    0.000000   18.100000    0.000000    0.706500
# max    498.000000   73.534100   22.000000   25.650000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean     6.132826   85.205988    2.522406   15.095808  512.335329   18.919162
# ...

# %%
Low_Crime.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  166.000000  166.000000  166.000000  166.000000  166.000000  166.000000
# mean   192.018072    0.094975   20.213855    7.251627    0.036145    0.475096
# std    129.142321    0.064579   28.788535    5.981559    0.187215    0.057182
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%     81.250000    0.044783    0.000000    3.380000    0.000000    0.431500
# 50%    181.500000    0.078855    0.000000    5.255000    0.000000    0.458000
# 75%    290.500000    0.140010   30.000000    9.407500    0.000000    0.515000
# max    506.000000    0.259150  100.000000   27.740000    1.000000    0.624000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  166.000000  166.000000  166.000000  166.000000  166.000000  166.000000
# mean     6.399211   51.144578    4.904615    4.138554  305.602410   17.974096
# ...

# %% [markdown]
# The median home value for homes in low crime areas is $233,500 versus $190,000 in high crime areas which supports the hypothesis made earlier.

# %% [markdown]
# Quality Schools affect on Home Value
#
# Another widely accepted belief is that better quality schools leads to higher home values. The median pupil to teacher ratio in the entire data set is 19 students per 1 teacher. High-quality schools will have a ratio below 19 and low quality schools will have a ratio above 19.

# %%
Good = df['ptratio'] < 19
Bad = df['ptratio'] > 19
Good_Schools = df[Good]
Bad_Schools = df[Bad]

# %%
print(Good_Schools.describe())
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean   185.345455    0.421422   17.912121    7.531879    0.090909    0.510891
# std     95.208222    0.702474   27.939064    5.618213    0.288355    0.111526
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%     97.000000    0.053720    0.000000    3.410000    0.000000    0.437000
# 50%    188.000000    0.102900    0.000000    6.090000    0.000000    0.488000
# 75%    266.000000    0.407710   28.000000   10.010000    0.000000    0.544000
# max    353.000000    3.321050  100.000000   19.580000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     6.514739   58.066667    4.341350    4.496970  307.533333   16.676970
# ...

# %%
print(Bad_Schools.describe())
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean   319.624242    6.359623    3.206061   15.172061    0.030303    0.605782
# std    159.994449    9.539114   12.151732    6.119595    0.171942    0.097295
# min     14.000000    0.013600    0.000000    1.250000    0.000000    0.410000
# 25%    137.000000    0.195390    0.000000    8.560000    0.000000    0.538000
# 50%    378.000000    3.693110    0.000000   18.100000    0.000000    0.609000
# 75%    449.000000    9.187020    0.000000   18.100000    0.000000    0.693000
# max    506.000000   73.534100   80.000000   27.740000    1.000000    0.770000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     6.012158   78.713939    3.047776   14.872727  513.357576   20.209091
# ...

# %% [markdown]
# As hypothesized, schools with higher pupil-teacher ratios have median home values of $184,000 while those with lower pupil-teacher ratios have a median home value of $240,000.

# %% [markdown]
# Visual representation of data for homes near Charles River

# %%
ax = Good_Schools.plot.scatter(x = 'ptratio', y = 'medv',c = 'darkblue')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = Bad_Schools.plot.scatter(x='ptratio', y='medv',c='darkblue')
# Out:
# <img src="data:image/png;base64,..." width="640">
